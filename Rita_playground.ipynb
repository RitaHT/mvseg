# %% [markdown]
# ### MobileViT Playground
# MobileViT Paper: https://arxiv.org/abs/2110.02178 (2021)
#
# DeepLabV3 Paper: https://arxiv.org/abs/1706.05587 (2017)
#
# Moco self-supervised pretraining: https://arxiv.org/abs/1911.05722 (2019)
#
# Goal:
#
# *   Blank MobileViT
# *   MobileViT w/ given pretrained weights
# *   MobileViT w/ self-supervised pretraining

# %%
# !pip install -q "monai-weekly[nibabel, tqdm, einops]"
# !pip install timm
from tqdm.auto import tqdm
# !pip install transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 68.1 MB/s eta 0:00:00
# Collecting timm
#   Downloading timm-1.0.7-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.18.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.23.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.5.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-1.0.7
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)

# %%
import os
from os import listdir, path
import time
import numpy as np
import nibabel as nib #for reading .nii.gz format MRI files
import pylab as plt #use pyplot in matplotlib instead, pylab is about to archived
import pandas as pd
from sklearn.model_selection import train_test_split
import cv2
import pickle

import torchvision.transforms as trans
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models.segmentation.deeplabv3 import DeepLabHead
from torch import from_numpy

import monai
from monai.data import CacheDataset, DataLoader, CSVDataset, Dataset
from monai.data.utils import pad_list_data_collate
from monai.losses import DiceCELoss
from monai.metrics import DiceMetric

from monai.transforms import (
    EnsureChannelFirstd,
    AsDiscreted, AsDiscrete,
    Compose,
    LoadImaged, LoadImage,
    SplitDimd,SplitDim,
    Orientationd,
    Randomizable,
    Resized,
    CenterSpatialCropd,
    ScaleIntensityd, ScaleIntensity,
    ScaleIntensityRanged, ScaleIntensityRange,
    Spacingd,
    EnsureTyped,
    ToTensord,
    NormalizeIntensityd, NormalizeIntensity,
    RandSpatialCropd,
    RandRotated,
    RandFlipd,
    RandAdjustContrastd,
    SaveImage
)


# %matplotlib inline

# %%
# set up model save directory
from google.colab import drive
drive.mount('/content/drive')

#import sys
#sys.path += '/content/drive/MyDrive/harini_lab_memo'
#%cd drive
#%cd MyDrive
#%cd harini_lab_memo
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Try Segmentation

# %% [markdown]
# ### Explore images
# ProstateX dataset (cleaned version): https://rcuocolo.github.io/PROSTATEx_masks/
#
# Original version: https://www.cancerimagingarchive.net/collection/prostatex/

# %%
os.chdir("/content/drive/MyDrive/harini_lab/")
cwd = os.getcwd() #/Users/rita/Desktop/
print(cwd)
# Out:
# /content/drive/MyDrive/harini_lab

# %%
# /lesions/ includes Images, Masks, Original_coordinate_markers, && image_list.csv
# /prostate/ includes Images, mask_prostate, mask_pz, mask_tz, && image_list.csv
file_dir = '/content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_only/'
#file_dir2 = file_dir.replace("lesions","prostate")

# check the csv with filed names
csvFilePath = os.path.join(file_dir,'slices_only_total.csv')
csvFile = pd.read_csv(csvFilePath) #lesions_total
csvFile.head()
# Out:
#              chID                       ID  Clinically Significant  \
# 0  ProstateX-0000  ProstateX-0000-Finding1                    True
# 1  ProstateX-0001  ProstateX-0001-Finding1                   False
# 2  ProstateX-0002  ProstateX-0002-Finding1                    True
# 3  ProstateX-0002  ProstateX-0002-Finding2                   False
# 4  ProstateX-0003  ProstateX-0003-Finding1                   False
#
#      Gleason Grade Group                                          ADC_image  \
# 0                      3  PROSTATEx/Files/lesions/Images/ADC/ProstateX-0...
# 1                      1  PROSTATEx/Files/lesions/Images/ADC/ProstateX-0...
# 2                      2  PROSTATEx/Files/lesions/Images/ADC/ProstateX-0...
# 3                      1  PROSTATEx/Files/lesions/Images/ADC/ProstateX-0...
# 4  No biopsy information  PROSTATEx/Files/lesions/Images/ADC/ProstateX-0...
#
#                                             T2_image  \
# 0  PROSTATEx/Files/lesions/Images/T2/ProstateX-00...
# 1  PROSTATEx/Files/lesions/Images/T2/ProstateX-00...
# 2  PROSTATEx/Files/lesions/Images/T2/ProstateX-00...
# 3  PROSTATEx/Files/lesions/Images/T2/ProstateX-00...
# 4  PROSTATEx/Files/lesions/Images/T2/ProstateX-00...
#
#                                             ADC_mask  \
# 0  PROSTATEx/Files/lesions/Masks/ADC/ProstateX-00...
# 1  PROSTATEx/Files/lesions/Masks/ADC/ProstateX-00...
# 2  PROSTATEx/Files/lesions/Masks/ADC/ProstateX-00...
# 3  PROSTATEx/Files/lesions/Masks/ADC/ProstateX-00...
# 4  PROSTATEx/Files/lesions/Masks/ADC/ProstateX-00...
#
#                                              T2_mask      ADC_shape  \
# 0  PROSTATEx/Files/lesions/Masks/T2/ProstateX-000...  (84, 128, 19)
# 1  PROSTATEx/Files/lesions/Masks/T2/ProstateX-000...  (84, 128, 19)
# 2  PROSTATEx/Files/lesions/Masks/T2/ProstateX-000...  (84, 128, 19)
# 3  PROSTATEx/Files/lesions/Masks/T2/ProstateX-000...  (84, 128, 19)
# 4  PROSTATEx/Files/lesions/Masks/T2/ProstateX-000...  (84, 128, 19)
#
#          T2_shape                                    ADC_image_slice  \
# 0  (384, 384, 19)  PROSTATEx/Files/slices_only/ADC/Images/Prostat...
# 1  (384, 384, 19)  PROSTATEx/Files/slices_only/ADC/Images/Prostat...
# 2  (384, 384, 19)  PROSTATEx/Files/slices_only/ADC/Images/Prostat...
# 3  (384, 384, 19)  PROSTATEx/Files/slices_only/ADC/Images/Prostat...
# 4  (384, 384, 21)  PROSTATEx/Files/slices_only/ADC/Images/Prostat...
#
#                                       ADC_mask_slice  \
# 0  PROSTATEx/Files/slices_only/ADC/Masks/Prostate...
# 1  PROSTATEx/Files/slices_only/ADC/Masks/Prostate...
# 2  PROSTATEx/Files/slices_only/ADC/Masks/Prostate...
# 3  PROSTATEx/Files/slices_only/ADC/Masks/Prostate...
# 4  PROSTATEx/Files/slices_only/ADC/Masks/Prostate...
#
#                                       T2_image_slice  \
# 0  PROSTATEx/Files/slices_only/T2/Images/Prostate...
# 1  PROSTATEx/Files/slices_only/T2/Images/Prostate...
# 2  PROSTATEx/Files/slices_only/T2/Images/Prostate...
# 3  PROSTATEx/Files/slices_only/T2/Images/Prostate...
# 4  PROSTATEx/Files/slices_only/T2/Images/Prostate...
#
#                                        T2_mask_slice ADC_slice_shape  \
# 0  PROSTATEx/Files/slices_only/T2/Masks/ProstateX...    (84, 128, 3)
# 1  PROSTATEx/Files/slices_only/T2/Masks/ProstateX...    (84, 128, 4)
# 2  PROSTATEx/Files/slices_only/T2/Masks/ProstateX...    (84, 128, 5)
# 3  PROSTATEx/Files/slices_only/T2/Masks/ProstateX...    (84, 128, 4)
# 4  PROSTATEx/Files/slices_only/T2/Masks/ProstateX...    (84, 128, 5)
#
#   T2_slice_shape
# 0  (384, 384, 4)
# 1  (384, 384, 4)
# 2  (384, 384, 4)
# 3  (384, 384, 4)
# 4  (384, 384, 4)

# %%
'''
plt.plot(df['ADC_min'])
plt.plot(df['ADC_max'])
plt.plot(df['ADC_mean'])
plt.plot(df['ADC_std'])
'''

# %%
i=1
eximage_path = os.path.join(cwd, csvFile['ADC_image_slice'][i])
exmask_path = os.path.join(cwd, csvFile['ADC_mask_slice'][i])
eximage_a = nib.load(eximage_path)
exmask_a  = nib.load(exmask_path)
eximage = eximage_a.get_fdata()
exmask  = exmask_a.get_fdata()
#print(eximage_a.affine)
#print(eximage_a.header)

print(exmask.min())
print(exmask.max())
print(exmask.mean())
print(exmask.std())
# Out:
# 0.0
# 0.9999999997671694
# 0.002836681546958581
# 0.053184911244630845

# %%
'''#eximg.orthoview() #NiBabel viewer not openning
# show the central slice: ex.19//2 = 9   ex.7//2 = 3
plt.imshow(eximage[:, :, eximage.shape[2] // 2].T, cmap='Greys_r')
plt.imshow(exmask[:, :, exmask.shape[2] // 2].T,  cmap='Reds', alpha=0.3)
'''

# %%
'''
print(batch_data["image"].affine)
print(batch_data["image"].meta)
print(inputs[0].affine)
print(inputs[0].meta)
image_slices = inputs[j].squeeze(0)
print(image_slices.affine)
print(image_slices.meta)
'''
# Out:
# tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64)
# {'qoffset_z': tensor([-87.9320]), 'dim_info': tensor([54], dtype=torch.uint8), 'quatern_b': tensor([-1.0182e-10]), 'srow_y': tensor([[ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02]]), space: [RAS], 'as_closest_canonical': tensor([False]), 'filename_or_obj': ['PROSTATEx/Files/slices_only/ADC/Images/ProstateX-0002-Finding1_image_slices.nii.gz'], 'intent_p1': tensor([0.]), original_channel_dim: tensor([2]), 'scl_slope': tensor([nan]), 'srow_x': tensor([[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01]]), 'qform_code': tensor([1], dtype=torch.int16), 'pixdim': tensor([[-1.,  2.,  2.,  3.,  1.,  1.,  1.,  1.]]), 'quatern_c': tensor([-0.9929]), 'dim': tensor([[  3,  84, 128,   5,   1,   1,   1,   1]], dtype=torch.int16), 'toffset': tensor([0.]), 'session_error': tensor([0], dtype=torch.int16), 'slice_end': tensor([0], dtype=torch.int16), 'slice_duration': tensor([0.]), 'glmax': tensor([0], dtype=torch.int32), 'srow_z': tensor([[ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01]]), 'bitpix': tensor([16], dtype=torch.int16), 'qoffset_x': tensor([91.5336]), 'xyzt_units': tensor([10], dtype=torch.uint8), affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'cal_max': tensor([0.]), original_affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'sform_code': tensor([1], dtype=torch.int16), 'intent_p3': tensor([0.]), 'slice_start': tensor([0], dtype=torch.int16), 'intent_p2': tensor([0.]), 'vox_offset': tensor([0.]), 'slice_code': tensor([0], dtype=torch.uint8), 'extents': tensor([0], dtype=torch.int32), 'glmin': tensor([0], dtype=torch.int32), 'datatype': tensor([4], dtype=torch.int16), 'intent_code': tensor([0], dtype=torch.int16), 'quatern_d': tensor([-0.1193]), 'sizeof_hdr': tensor([348], dtype=torch.int32), 'scl_inter': tensor([nan]), 'qoffset_y': tensor([-143.4072]), spatial_shape: tensor([[ 84, 128,   1]], dtype=torch.int16), 'cal_min': tensor([0.])}
# tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64)
# {'qoffset_z': tensor([-87.9320]), 'dim_info': tensor([54], dtype=torch.uint8), 'quatern_b': tensor([-1.0182e-10]), 'srow_y': tensor([[ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02]]), space: [RAS], 'as_closest_canonical': tensor([False]), 'filename_or_obj': ['PROSTATEx/Files/slices_only/ADC/Images/ProstateX-0002-Finding1_image_slices.nii.gz'], 'intent_p1': tensor([0.]), original_channel_dim: tensor([2]), 'scl_slope': tensor([nan]), 'srow_x': tensor([[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01]]), 'qform_code': tensor([1], dtype=torch.int16), 'pixdim': tensor([[-1.,  2.,  2.,  3.,  1.,  1.,  1.,  1.]]), 'quatern_c': tensor([-0.9929]), 'dim': tensor([[  3,  84, 128,   5,   1,   1,   1,   1]], dtype=torch.int16), 'toffset': tensor([0.]), 'session_error': tensor([0], dtype=torch.int16), 'slice_end': tensor([0], dtype=torch.int16), 'slice_duration': tensor([0.]), 'glmax': tensor([0], dtype=torch.int32), 'srow_z': tensor([[ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01]]), 'bitpix': tensor([16], dtype=torch.int16), 'qoffset_x': tensor([91.5336]), 'xyzt_units': tensor([10], dtype=torch.uint8), affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'cal_max': tensor([0.]), original_affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'sform_code': tensor([1], dtype=torch.int16), 'intent_p3': tensor([0.]), 'slice_start': tensor([0], dtype=torch.int16), 'intent_p2': tensor([0.]), 'vox_offset': tensor([0.]), 'slice_code': tensor([0], dtype=torch.uint8), 'extents': tensor([0], dtype=torch.int32), 'glmin': tensor([0], dtype=torch.int32), 'datatype': tensor([4], dtype=torch.int16), 'intent_code': tensor([0], dtype=torch.int16), 'quatern_d': tensor([-0.1193]), 'sizeof_hdr': tensor([348], dtype=torch.int32), 'scl_inter': tensor([nan]), 'qoffset_y': tensor([-143.4072]), spatial_shape: tensor([[ 84, 128,   1]], dtype=torch.int16), 'cal_min': tensor([0.])}
# tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64)
# {'qoffset_z': tensor([-87.9320]), 'dim_info': tensor([54], dtype=torch.uint8), 'quatern_b': tensor([-1.0182e-10]), 'srow_y': tensor([[ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02]]), space: [RAS], 'as_closest_canonical': tensor([False]), 'filename_or_obj': ['PROSTATEx/Files/slices_only/ADC/Images/ProstateX-0002-Finding1_image_slices.nii.gz'], 'intent_p1': tensor([0.]), original_channel_dim: tensor([2]), 'scl_slope': tensor([nan]), 'srow_x': tensor([[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01]]), 'qform_code': tensor([1], dtype=torch.int16), 'pixdim': tensor([[-1.,  2.,  2.,  3.,  1.,  1.,  1.,  1.]]), 'quatern_c': tensor([-0.9929]), 'dim': tensor([[  3,  84, 128,   5,   1,   1,   1,   1]], dtype=torch.int16), 'toffset': tensor([0.]), 'session_error': tensor([0], dtype=torch.int16), 'slice_end': tensor([0], dtype=torch.int16), 'slice_duration': tensor([0.]), 'glmax': tensor([0], dtype=torch.int32), 'srow_z': tensor([[ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01]]), 'bitpix': tensor([16], dtype=torch.int16), 'qoffset_x': tensor([91.5336]), 'xyzt_units': tensor([10], dtype=torch.uint8), affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'cal_max': tensor([0.]), original_affine: tensor([[[-2.0000e+00,  4.1021e-10, -8.3267e-17,  9.1534e+01],
#          [ 3.9854e-10,  1.9431e+00, -7.1051e-01, -1.4341e+02],
#          [ 9.7153e-11,  4.7368e-01,  2.9146e+00, -8.7932e+01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        dtype=torch.float64), 'sform_code': tensor([1], dtype=torch.int16), 'intent_p3': tensor([0.]), 'slice_start': tensor([0], dtype=torch.int16), 'intent_p2': tensor([0.]), 'vox_offset': tensor([0.]), 'slice_code': tensor([0], dtype=torch.uint8), 'extents': tensor([0], dtype=torch.int32), 'glmin': tensor([0], dtype=torch.int32), 'datatype': tensor([4], dtype=torch.int16), 'intent_code': tensor([0], dtype=torch.int16), 'quatern_d': tensor([-0.1193]), 'sizeof_hdr': tensor([348], dtype=torch.int32), 'scl_inter': tensor([nan]), 'qoffset_y': tensor([-143.4072]), spatial_shape: tensor([[ 84, 128,   1]], dtype=torch.int16), 'cal_min': tensor([0.])}

# %% [markdown]
# #### check data

# %%
'''print(inputs[0].squeeze(0).shape)
print(batch_data["image"].shape)
fig = plt.figure(figsize=(5, 5))
for i in range(len(inputs)):
    for j in range(3): #three-channel
        num_slice = (i*3+j)+1
        a = plt.subplot(3, 3, num_slice); a.axis("off"), a.set_title("Slice {}/{}".format(num_slice, batch_data["image"].shape[1]),fontsize=8)
        plt.imshow(inputs[i].squeeze(0)[j,:,:].T, cmap="gray")
        plt.imshow(labels[i].squeeze(0)[j,:,:].T,  cmap='Reds', alpha=0.3)
fig.suptitle("Example slices from dataset {}, one MRI".format(filename),fontsize=10) # batch_size=1
plt.show()
'''
# Out:
# torch.Size([3, 84, 128])
# torch.Size([1, 5, 84, 128])

# %%
'''
# save to [3,256,256] slices (work in progress)
output_dir = os.path.join(cwd, 'PROSTATEx/Files/slices_fixed/ADC')
os.makedirs(output_dir, exist_ok=True)
os.makedirs(os.path.join(output_dir, 'Images'), exist_ok=True)
os.makedirs(os.path.join(output_dir, 'Masks'), exist_ok=True)

slice_info_image = []
slice_info_mask = []
IDs = []
chIDs = []
ADC_shape = []

for i in range(len(csvFile)): #len(csvFile)
    image_filename = csvFile['ADC_image_slice'][i]
    mask_filename = csvFile['ADC_mask_slice'][i]
    filename = csvFile['ID'][i]
    chID = csvFile['chID'][i]

    image_path = os.path.join(cwd, image_filename)
    mask_path = os.path.join(cwd, mask_filename)

    # Load image and mask using nibabel
    image_nifti = nib.load(image_path)
    mask_nifti = nib.load(mask_path)
    #print(image_nifti.affine)
    #print(image_nifti.header)

    # Load image and mask
    image = image_nifti.get_fdata()
    mask = mask_nifti.get_fdata()
    #print(image.shape)
    #print(mask.shape)

    image = np.transpose(image, (2, 0, 1))
    image = np.expand_dims(image, axis=0)
    mask = np.transpose(mask, (2, 0, 1))
    mask = np.expand_dims(mask, axis=0)

    image = torch.from_numpy(image)
    mask = torch.from_numpy(mask)
    #print(image.shape)
    #print(mask.shape)

    # Split image and mask into slices

    inputs, labels = (
        SplitImageCustom(dim = 1)(image), #[2, 19, 256, 256] -> [12, 3, 256, 256]
        SplitImageCustom(dim = 1)(mask),
    )
    #print(len(inputs))

    # Save slices
    for j in range(len(inputs)):
        inputs[j].squeeze(0)
        image_slices = inputs[j].squeeze(0)
        mask_slices = labels[j].squeeze(0)
        #print(f"image_split[{j}].shape: {image_slices.shape}")
        combined_image_path = os.path.join(output_dir, f'Images/{filename}_image_slices_{j}.nii.gz')
        combined_mask_path = os.path.join(output_dir, f'Masks/{filename}_mask_slices_{j}.nii.gz')

        combined_image_nifti = nib.Nifti1Image(image_slices, image_nifti.affine, image_nifti.header)
        combined_mask_nifti = nib.Nifti1Image(mask_slices, mask_nifti.affine, mask_nifti.header)

        nib.save(combined_image_nifti, combined_image_path)
        nib.save(combined_mask_nifti, combined_mask_path)
        print(f"Saved {combined_image_path}")

        slice_info_image.append(combined_image_path)
        slice_info_mask.append(combined_mask_path)
        IDs.append(filename)
        chIDs.append(chID)
        ADC_shape.append(image_slices.shape)


'''
# Out:
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0000-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0001-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0001-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0002-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0002-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0002-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0002-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0003-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0003-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0003-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0003-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0004-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0004-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0004-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0005-Finding0_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0005-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0006-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0006-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0006-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0007-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0007-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0008-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0008-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0009-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0009-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0010-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0010-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0011-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0011-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0012-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0012-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0012-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0012-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0013-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0014-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0014-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0014-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0015-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0015-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0015-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0015-Finding1_image_slices_3.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0016-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0016-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0017-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0018-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0018-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0019-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0019-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0019-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0020-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0021-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0021-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0021-Finding4_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0022-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0022-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0023-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0023-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0023-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0023-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0024-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0024-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0025-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0025-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0026-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0026-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0026-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0027-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0028-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0028-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0028-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0029-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0030-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0030-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0031-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0031-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0031-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0031-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0032-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0032-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0033-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0033-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0033-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0033-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0034-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0034-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0034-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0035-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0035-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0035-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0035-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0035-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0036-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0036-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0037-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0037-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0037-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding2_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0038-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0039-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0039-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0040-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0040-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0040-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0040-Finding2_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0040-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0041-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0041-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0042-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0042-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0043-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0043-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0044-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0044-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0044-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0044-Finding1_image_slices_3.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0045-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0046-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0046-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0046-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0046-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0047-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0048-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0048-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0048-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0049-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0049-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0050-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0050-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0050-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0050-Finding1_image_slices_3.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0051-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0051-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0053-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0053-Finding4_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0054-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0054-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0054-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0054-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0055-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0055-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0055-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0057-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0057-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0057-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0057-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0058-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0058-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0059-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0059-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0060-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0061-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0061-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0062-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0062-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0063-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0064-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0064-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0065-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0065-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0065-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0066-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0066-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0067-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0067-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0067-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0067-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0067-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0068-Finding3_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0069-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0069-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0070-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0070-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0070-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0070-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0070-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0071-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0071-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0072-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0072-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0073-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0073-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0074-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0075-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0075-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0075-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0076-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0076-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0077-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0077-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0078-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0078-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0079-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0079-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0081-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0081-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0081-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0082-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0082-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0083-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0083-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0083-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0084-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0084-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0084-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0084-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0085-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0085-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0085-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0085-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0085-Finding4_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0086-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0086-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0086-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0087-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0087-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0087-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0088-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0088-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0088-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0088-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0089-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0090-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0091-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0091-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0092-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0092-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0093-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0093-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0094-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0094-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0094-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0095-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0095-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0095-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0095-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0095-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0096-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0096-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0097-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0097-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0098-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0098-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0099-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0099-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0099-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0099-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0100-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0100-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0100-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0100-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0101-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0101-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0101-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0101-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0101-Finding2_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0102-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0102-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0103-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0103-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0103-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0103-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0103-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0104-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0104-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0104-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0104-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0104-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0105-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0105-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0105-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0106-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0106-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0106-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0107-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0107-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0108-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0108-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0108-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0108-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0109-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0109-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0109-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0110-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0110-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0110-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0110-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0110-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0111-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0111-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0112-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0112-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0113-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0113-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0114-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0114-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0114-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0114-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0115-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0116-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0116-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0117-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0117-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0117-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0118-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0118-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0118-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0119-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0120-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0120-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0120-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding1_image_slices_3.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0121-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0122-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0122-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0122-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0122-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0123-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0123-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0124-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0124-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0125-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0125-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0126-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0126-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0126-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0126-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0127-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0127-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0128-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0129-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0130-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0130-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0130-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0130-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0131-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0131-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0131-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0132-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0133-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0133-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0134-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0134-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0134-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0134-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0135-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0135-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0135-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0135-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0136-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0136-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0136-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0136-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0136-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0137-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0139-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0139-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0139-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0139-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0140-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0140-Finding1_image_slices_1.nii.gz
# ...
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0160-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0161-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0161-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0161-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0161-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0162-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0162-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0163-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0163-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0163-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0163-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0164-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0164-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0165-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0165-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0165-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0166-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0167-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0167-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0168-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0169-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0169-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0170-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0170-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0170-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0171-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0171-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0171-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0171-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0171-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0172-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0173-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0173-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0173-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0173-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0174-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0174-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0174-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0175-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0175-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0176-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0177-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0177-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0177-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0177-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0177-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0178-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0179-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0179-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0179-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0179-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0180-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0180-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0181-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0181-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0181-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0182-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0182-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0183-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0183-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0184-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0184-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0185-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0185-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0186-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0186-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0186-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0186-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0187-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0187-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0187-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0187-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0188-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0188-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0189-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0190-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0190-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0190-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0190-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0191-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0191-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0192-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0192-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0192-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0192-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding4_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0193-Finding4_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0194-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0194-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0195-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding3_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0196-Finding3_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0197-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0197-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0198-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0199-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0199-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0199-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0199-Finding2_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0199-Finding2_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0200-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0200-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0201-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0201-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0201-Finding1_image_slices_2.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0202-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0202-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0202-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0203-Finding1_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0203-Finding1_image_slices_1.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0203-Finding2_image_slices_0.nii.gz
# Saved /content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/ADC/Images/ProstateX-0203-Finding2_image_slices_1.nii.gz

# %%
'''
i=498
eximage_path = slice_info_image[i]
exmask_path = slice_info_mask[i]
eximage_a = nib.load(eximage_path)
exmask_a  = nib.load(exmask_path)
eximage = eximage_a.get_fdata()
exmask = exmask_a.get_fdata()
print(eximage.shape)
print(exmask.shape)
plt.imshow(eximage[1, :, :].T, cmap='Greys_r')
plt.imshow(exmask[1, :, :].T,  cmap='Reds', alpha=0.3)
'''
# Out:
# (3, 84, 128)
# (3, 84, 128)

# %%
file_dir = '/content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/'
csvFilePath = os.path.join(file_dir,'slices_fixed_total.csv')
csvFile = pd.read_csv(csvFilePath) #lesions_total
csvFile.head()
print(csvFile.shape)
# Out:
# (523, 4)

# %%
'''
ADC_name = csvFile['ADC_image_slice'] #ex.[84/120/128, 106/128, 19/21...]
#T2_name = csvFile['T2_image_slice'] #ex.[320/384, 320/384, 19/21...]
ADC_shape =[]
#T2_shape =[]

for i in range (len(csvFile)):
    eximg_filename1 = ADC_name[i]
    #eximg_filename2 = T2_name[i]

    eximg1 = nib.load(os.path.join(cwd, eximg_filename1))
    exdata1 = eximg1.get_fdata()
    exdata1_shape = exdata1.shape
    ADC_shape.append(exdata1_shape)

#Combine to csvFile
#csvFile['T2_slice_shape'] = T2_shape
csvFile['ADC_slice_shape'] = ADC_shape

# %%
#csvFile.head()
#csvFile.to_csv('slices_fixed_total.csv', index=False)

# %%
len(csvFile)
# Out:
# 299

# %%
file_dir = '/content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/'
#file_dir2 = file_dir.replace("lesions","prostate")

# check the csv with filed names
csvFilePath = os.path.join(file_dir,'slices_fixed_total.csv')
csvFile = pd.read_csv(csvFilePath) #lesions_total
csvFile.head()
# get data
ADC_min =[]
ADC_max =[]
ADC_mean =[]
ADC_std =[]

for i in range (len(csvFile)):
    eximg_filename1 = os.path.join(cwd, csvFile['ADC_mask_slice'][i])

    eximg1 = nib.load(eximg_filename1).get_fdata()
    exdata1_min = np.min(eximg1)
    exdata1_max = np.max(eximg1)
    exdata1_mean = np.mean(eximg1)
    exdata1_std = np.std(eximg1)

    ADC_min.append(exdata1_min)
    ADC_max.append(exdata1_max)
    ADC_mean.append(exdata1_mean)
    ADC_std.append(exdata1_std)

data = {
    "ADC_min": ADC_min,
    "ADC_max": ADC_max,
    "ADC_mean": ADC_mean,
    "ADC_std": ADC_std
}

df = pd.DataFrame(data)

plt.plot(df['ADC_min'])
plt.plot(df['ADC_max'])
plt.plot(df['ADC_mean'])
plt.plot(df['ADC_std'])

# %%
plt.plot(df['ADC_std'])

# %%
'''
len(slice_info_image) #523
data = {'ID': IDs, 'chID': chIDs, 'ADC_image_slice': slice_info_image, 'ADC_mask_slice': slice_info_mask, 'ADC_slice_hape': ADC_shape}
df = pd.DataFrame(data)
df
'''
# Out:
#                           ID            chID  \
# 0    ProstateX-0000-Finding1  ProstateX-0000
# 1    ProstateX-0001-Finding1  ProstateX-0001
# 2    ProstateX-0001-Finding1  ProstateX-0001
# 3    ProstateX-0002-Finding1  ProstateX-0002
# 4    ProstateX-0002-Finding1  ProstateX-0002
# ..                       ...             ...
# 558  ProstateX-0202-Finding2  ProstateX-0202
# 559  ProstateX-0203-Finding1  ProstateX-0203
# 560  ProstateX-0203-Finding1  ProstateX-0203
# 561  ProstateX-0203-Finding2  ProstateX-0203
# 562  ProstateX-0203-Finding2  ProstateX-0203
#
#                                        ADC_image_slice  \
# 0    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 1    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 2    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 3    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 4    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# ..                                                 ...
# 558  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 559  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 560  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 561  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
# 562  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...
#
#                                         ADC_mask_slice ADC_slice_hape
# 0    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...   (3, 84, 128)
# 1    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...   (3, 84, 128)
# 2    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...   (3, 84, 128)
# 3    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...   (3, 84, 128)
# 4    /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...   (3, 84, 128)
# ..                                                 ...            ...
# 558  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...  (3, 128, 106)
# 559  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...  (3, 128, 106)
# 560  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...  (3, 128, 106)
# 561  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...  (3, 128, 106)
# 562  /content/drive/MyDrive/harini_lab/PROSTATEx/Fi...  (3, 128, 106)
#
# [563 rows x 5 columns]

# %%
#df.to_csv('slices_fixed_total.csv', index=False)

# %%
# split into n*[3,256,256] (work in progress)
from monai.transforms.transform import Transform, MapTransform

class SplitImageCustomd(MapTransform): #not using for now
    def __init__(self, keys, split_size: int = 3, dim: int = 1, keepdim: bool = True, update_meta=True):
        super().__init__(keys)
        self.splitter = SplitImageCustom(split_size=split_size, dim=dim, keepdim=keepdim, update_meta=update_meta)

    def __call__(self, data):
        '''
        Apply transform to each [key]
        '''
        d = dict(data)
        for key in self.keys:
            d[key] = self.splitter(d[key])
        return d

class SplitImageCustom(Transform):
    def __init__(self, split_size: int = 3, dim: int = 1, keepdim: bool = True, update_meta=True) -> None:
        self.dim = dim #assume ChannelFirst, and dim=0 is batchsize
        self.keepdim = keepdim
        self.update_meta = update_meta
        self.split_size = split_size

    def __call__(self, img: torch.Tensor) -> torch.Tensor:
        """
        Apply the transform to `img`.
        """

        if isinstance(img, torch.Tensor):
            if img.dim() == 3: #[5, 256, 256] -> [1,5,256,256]
                img = img.unsqueeze(0)  # Add batch dimension if missing: so that it can be used in dictionary form

            #check if at least 3 slices
            current_channels = img.shape[self.dim] #img.shape[1]= 2~10, [1, x, 256, 256], tensor
            if current_channels < self.split_size:
                img = img.repeat(1, self.split_size, 1, 1)
            #print(f"current_channels: ", current_channels)

            outputs = list(torch.split(img, self.split_size, self.dim)) #6 * [1, 3, 256, 256], list
            #print(f"Is tensor: within: ", len(outputs))

            #print(f"output last shape: ", outputs[-1].shape)

            # check last item dimension (not checked for np.array yet)
            ch = outputs[-1].shape[self.dim]
            if ch != self.split_size: #[1,1/2,256,256] not [1,3,256,256]
                #print(f"outputs[-1] shape: {outputs[-1].shape}")
                #additional_channels = self.split_size - ch #3-1 or 3-2
                '''
                last_channel_repeated = outputs[-1][:, -1:, :, :].repeat(1, additional_channels, 1, 1) #repeat the last channel of [1,1/2,256,256]
                out_expand = torch.cat((outputs[-1], last_channel_repeated), dim=self.dim)
                '''
                #assume self.dim=1
                pad = img[:,-3:-1,:,:] #3rd last, 2nd last slices
                out_expand = torch.cat((pad, outputs[-1][:, -1:, :, :]), dim=self.dim)
                #print(f"out_expand shape: {out_expand.shape}")
                outputs[-1] = out_expand
                #print(f"outputs[-1] shape: {outputs[-1].shape}")

            # check if batch is >1, so that DeepLabHead can work (batchnorm layer)
            # hardcoded. is there a better way?
            '''
            if len(outputs) == 1:
                #print(len(outputs))   #1 * [1,3,256,256]
                outputs = outputs * 2 #2 * [1,3,256,256] : minimal shown 6 slices
            '''
            # put it back to a torch tensor of [batch_size, dim, h, w]: put it outside?
            #combined_tensor = torch.cat(outputs, dim=0) #[6,3,256,256]
            #combined_tensor = outputs

        else:
            #np.array objects
            #assume only use before dataloader?
            if img.ndim == 3: #[5, 256, 256] -> [1,5,256,256]
                img = img.expand_dims(x, axis=0)  # Add batch dimension if missing: so that it can be used in dictionary form

            #check if at least 3 slices
            current_channels = img.shape[self.dim]

            outputs = np.split(img, current_channels//self.split_size, self.dim)
            print(f"This np.array ({img.shape}) split into {len(outputs)} images of shape {outputs[-1].shape}")

             # check last item dimension (not checked for np.array yet)
            ch = outputs[-1].shape[self.dim]
            if ch != self.split_size:
                #assume self.dim=1
                pad = img[:,-3:-1,:,:] #3rd last, 2nd last slices
                out_expand = np.concatenate((pad, outputs[-1][:, -1:, :, :]), axis=self.dim)

                #print(f"out_expand shape: {out_expand.shape}")
                outputs[-1] = out_expand

                if len(outputs) == 1:
                    outputs = outputs * 2
                    print(f"len(outputs): {len(outputs)}")

            combined_tensor = np.concatenate(outputs, axis=0)

        return combined_tensor

# %% [markdown]
# ### Put into dataset using MONAI
# https://docs.monai.io/en/latest/transforms.html#dictionary-transforms

# %% [markdown]
# #### Directory

# %%
# !nvcc --version
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
os.chdir("/content/drive/MyDrive/harini_lab/")
cwd = os.getcwd() #/Users/rita/Desktop/
print(cwd)
# Out:
# /content/drive/MyDrive/harini_lab

# %%
# load files
file_dir = '/content/drive/MyDrive/harini_lab/PROSTATEx/Files/slices_fixed/'
csvFilePath_total = os.path.join(file_dir,'slices_fixed_total.csv') #lesions_total.csv
csvFilePath_train = os.path.join(file_dir,'slices_train.csv')#lesion_train.csv
csvFilePath_val = os.path.join(file_dir,'slices_val.csv') #lesion_val.csv
#df = pd.read_csv(csvFilePath_total) #(299,8)

# %%
'''
#train val split
df = pd.read_csv(csvFilePath_total) #(299,16)

train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
train_df = train_df.sort_index()
val_df = val_df.sort_index()

train_df = train_df.rename_axis('original_index')
val_df = val_df.rename_axis('original_index')

train_df.to_csv(csvFilePath_train)
val_df.to_csv(csvFilePath_val)

print(train_df.shape) #(239,16) (418,4)
print(val_df.shape) #(60,16) (105,4)
train_df.head()
'''
# Out:
# "\n#train val split\ndf = pd.read_csv(csvFilePath_total) #(299,16)\n\ntrain_df, val_df = train_test_split(df, test_size=0.2, random_state=42)\ntrain_df = train_df.sort_index()\nval_df = val_df.sort_index()\n\ntrain_df = train_df.rename_axis('original_index')\nval_df = val_df.rename_axis('original_index')\n\ntrain_df.to_csv(csvFilePath_train)\nval_df.to_csv(csvFilePath_val)\n\nprint(train_df.shape) #(239,16) (418,4)\nprint(val_df.shape) #(60,16) (105,4)\ntrain_df.head()\n"

# %% [markdown]
# #### Load

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"],channel_dim=0), #default NibelReader #[84, 128, 19] #"ADC_image", "ADC_mask"
        EnsureChannelFirstd(keys=["image", "label"]), #[19, 84, 128]
        ScaleIntensityRanged(keys=["image"], a_min=0, a_max=3500, b_min=0, b_max=1, clip=True), #ADC

        #spacing? why need? assume has affine in metadata
        # DW sequence: 2 mm in-plane and 3.6 mm slice thickness
        #Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        Resized(keys=["image", "label"], spatial_size=(288,288), anti_aliasing=True), #[1, 288, 288]
        CenterSpatialCropd(keys=["image", "label"], roi_size=(256,256)), #[1, 256, 256]
        EnsureTyped(keys=["image", "label"], device=device, track_meta=False), #execute random transforms on GPU directly

        #data augmentations:
        RandRotated(keys=["image", "label"], prob=0.5, range_x=[-1.0, 1.0]), #random rotation
        #RandFlipd(keys=["image", "label"], prob=0.1, spatial_axis=0), #random flip error
        #RandFlipd(keys=["image", "label"], prob=0.1, spatial_axis=1), #random flip
        #RandFlipd(keys=["image", "label"], prob=0.1, spatial_axis=2), #random flip

        RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.5, 2.0)), #ColorJitter in PyTorch

        ToTensord(keys=["image", "label"]),
        #NormalizeIntensityd(keys=["image"]),
    ]
)

val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"],channel_dim=0), #default NibelReader #[84, 128, 19] #"ADC_image", "ADC_mask"
        EnsureChannelFirstd(keys=["image", "label"]), #[19, 84, 128]
        ScaleIntensityRanged(keys=["image"], a_min=0, a_max=3500, b_min=0, b_max=1, clip=True), #ADC

        Resized(keys=["image", "label"], spatial_size=(288,288), anti_aliasing=True), #[1, 288, 288]
        CenterSpatialCropd(keys=["image", "label"], roi_size=(256,256)), #[1, 256, 256]
        EnsureTyped(keys=["image", "label"], device=device, track_meta=False), #execute random transforms on GPU directly
        # without data augmentations
        ToTensord(keys=["image", "label"]),
        #NormalizeIntensityd(keys=["image"]),
    ]
)

# %%
train_dataset_pre = CSVDataset( #change to CacheDataset for faster later:  train_dataset_pre
    src=csvFilePath_train,
    col_names=["ID","ADC_image_slice", "ADC_mask_slice"],
    col_groups={"image": "ADC_image_slice", "label": "ADC_mask_slice"}, #create new col, easier later switch to T2
    transform=train_transforms,
    # may not need to load so many columns
)
val_dataset = CSVDataset(
    src=csvFilePath_val,
    col_names=["ID","ADC_image_slice", "ADC_mask_slice"],
    col_groups={"image": "ADC_image_slice", "label": "ADC_mask_slice"}, #create new col, easier later switch to T2
    transform=val_transforms,
    # may not need to load so many columns
)

# %%
#train_dataset_pre[1]

# %%
train_dataset = CacheDataset(train_dataset_pre, cache_rate=1.0)
#train_dataset = train_dataset_pre
# Out:
# Loading dataset: 100%|██████████| 450/450 [00:34<00:00, 13.14it/s]

# %%
train_loader = DataLoader(train_dataset, batch_size=4) #num_workers=0, pin_memory=True)#, collate_fn=pad_list_data_collate) #(239) #still error?? #collate_fn=pad_list_data_collate
val_loader = DataLoader(val_dataset, batch_size=1)  # num_workers=0, pin_memory=True) #(60)

# %%
# plot the transformed image array
fig = plt.figure(figsize=(5, 5))
for i in range(5):
    a = plt.subplot(3, 3, i + 1); a.axis("off"); a.set_title(train_dataset[i]["ID"],fontsize=8) #chID
    print(train_dataset[i]["image"].shape)
    plt.imshow(train_dataset[i]["image"].cpu()[0,:,:].T, cmap="gray")
    plt.imshow(train_dataset[i]["label"].cpu()[0,:,:].T,  cmap='Reds', alpha=0.3)
fig.suptitle("Example slice from dataset[0~4]",fontsize=10)
plt.show()
# Out:
# torch.Size([3, 256, 256])
# torch.Size([3, 256, 256])
# torch.Size([3, 256, 256])
# torch.Size([3, 256, 256])
# torch.Size([3, 256, 256])

# %%
# plot the (19//3) * 3 channel image inputs that will be used in training, for now

#batch_data = next(iter(train_loader)) #dictionary object, len=8

i = 0
for batch_data in train_loader:
    i += 1
    if i == 6: #choose to see which example images
        break

    #print(batch_data["shape"]) #[84,128,5]'''
    input = batch_data["image"]
    label = batch_data["label"]
    #print(input.shape)
    print(input.shape) #[1,5,256,256]
# Out:
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 3, 256, 256])

# %%
#check
plt.imshow(input[0,1,:,:].cpu().T, cmap="gray") #0,1,2 / 3,4,5 / 6,7
plt.imshow(label[0,1,:,:].cpu().T, cmap= 'Reds', alpha=0.3)

# %%
print(np.min(input))
print(np.max(input))
# Out:
# 0.0
# 0.99999976

# %% [markdown]
# ### Try Training
# Modify to MONAI / transformer trainer later
#
# MONAI: https://docs.monai.io/en/stable/engines.html#trainer
#
# HF(transformer): https://huggingface.co/docs/transformers/main/en/training#finetune-with-trainer
#
# Reference training loop: https://colab.research.google.com/drive/1ebbMS5qNH0s7grA_cZSTu5MIo7vPXbYC?usp=sharing

# %% [markdown]
# #### Define

# %%
# Define MobileViT_DeepLabV3 model class
class MobileViT_DeepLabV3(nn.Module):
    def __init__(self, backbone, seg_head):
        super(MobileViT_DeepLabV3, self).__init__()
        self.backbone = backbone
        self.seg_head = seg_head
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, return_intermediate=False):
        outputs_base = self.backbone(x)
        inputs_seg = outputs_base[-1].to(device) #[batch, 256/512/1024, 8/32, 8/32] feature maps #backprop???
        outputs_seg = self.seg_head(inputs_seg) #[batch, 1, 8/32, 8/32] MetaTensor
        # need softmax(multiclass)/sigmoid(binary) activation to turn feature map into segmentation probability
        outputs_active = self.sigmoid(outputs_seg) #[batch, 1, 32, 32] #ex.max=0.8551, min=0.1949
        #print(outputs_active.max())
        #print(outputs_active.min())
        outputs_upsampled = F.interpolate(outputs_active, size=x.shape[-2:], mode='bilinear', align_corners=False) #[6, 1, 256, 256] #ex. max=0.8345, min=0.2594
        # assert(x.shape[-2:]==[256,256])
        # need a way to check outputs_seg, but cannot affect backprop
        #if return_intermediate:
        #    return outputs_upsampled, outputs_seg
        #else:
        return outputs_upsampled #outputs_upsampled

# %%
# Confirm models
# same as above

base_model = timm.create_model(
    'mobilevitv2_100.cvnets_in1k',
    pretrained=True,
    features_only=True,
    #output_stride=8,
).to(device)

seg_model = DeepLabHead(
    in_channels=512,  # Adjust if feature map from base_model differ
    num_classes=3,  # matching the input channel in mobilevitv2
    atrous_rates=(6,12,18) #from the paper, PyTorch default (12,24,36)
).to(device)

model = MobileViT_DeepLabV3(base_model, seg_model).to(device)

# %%
# Define Loss, Optimizer
# same as above
from monai.losses import DiceCELoss
from torch.nn import BCEWithLogitsLoss

torch.backends.cudnn.benchmark = True
#loss_function = BCEWithLogitsLoss()   #nn.CrossEntropyLoss()
loss_function = DiceCELoss(include_background=True, to_onehot_y=False, sigmoid=False, squared_pred=True) #1.0090 #to_onehot_y=True for [batch,1,3,256,256] #sigmoid already in the model? #why use squared_pred in denominator?

optimizer = torch.optim.AdamW(model.parameters(), lr=0.005, weight_decay=0.00005) #lr > weight_decay #as paper, base_model & seg_model? #0.0005
scaler = torch.cuda.amp.GradScaler()

# %%
# check loss again
model.train()
batch_data = next(iter(train_loader))
inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device),)

loss_function = DiceCELoss() #1.0090
with torch.cuda.amp.autocast():
    outputs_upsampled = model(inputs) #[batch,3,256,256]
    outputs_upsampled = outputs_upsampled.unsqueeze(1) #[batch, 1, 3,256,256]
    labels = labels.unsqueeze(1) #[batch, 1, 3,256,256]
    loss = loss_function(outputs_upsampled, labels) #1.0077 --> 1.9552
print(loss)

model.eval()
with torch.no_grad():
    outputs_upsampled_v = model(inputs)
    outputs_upsampled_v = outputs_upsampled_v.unsqueeze(1) #[batch,1,3,256,256]
    outputs_upsampled_v = discrete_pred(outputs_upsampled_v)
    labels_v = labels.unsqueeze(1) #[batch,1,3,256,256]
    labels_v = discrete_label(labels_v)
    dice_metric(y_pred=outputs_upsampled_v, y=labels_v) #num_class=shape[1]
mean_dice_val = dice_metric.aggregate().item()
#dice_metric.reset()
print(mean_dice_val)
# Out:
# metatensor(1.9759, device='cuda:0', grad_fn=<AliasBackward0>)
# 0.007327734492719173

# %%
fig = plt.figure(figsize=(5, 5))
a=plt.subplot(2,4,1); a.axis("off"); a.set_title("output",fontsize=10)
plt.imshow(outputs_upsampled_v[0,0,0,:,:].cpu().T, cmap="gray")
a=plt.subplot(2,4,2); a.axis("off"); a.set_title("label",fontsize=10)
plt.imshow(labels_v[0,0,0,:,:].cpu().T, cmap="gray")
a=plt.subplot(2,4,3); a.axis("off"); a.set_title("label",fontsize=10)
plt.imshow(labels[0,0,0,:,:].cpu().T, cmap="gray")
a=plt.subplot(2,4,4); a.axis("off"); a.set_title("input",fontsize=10)
plt.imshow(inputs[0,0,:,:].cpu().T, cmap="gray")
print(outputs_upsampled_v.min())
print(outputs_upsampled_v.max())
print(labels_v.min())
print(labels_v.max())
# Out:
# metatensor(0., device='cuda:0')
# metatensor(1., device='cuda:0')
# metatensor(0., device='cuda:0')
# metatensor(1., device='cuda:0')

# %%
plt.hist(labels.cpu().numpy().flatten(), bins=256, log=True)
plt.show()

# %%
plt.hist(labels_v.cpu().numpy().flatten(), bins=256, log=True)
plt.show()

# %%
#check dice metric
from monai.metrics import DiceMetric
dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False) #[batch,1,3,256,256] #The include_background parameter can be set to False to exclude the first category (channel index 0)
discrete_pred = AsDiscrete(to_onehot=None, threshold=0.5)  #should be probability #to_onehot=number of classes, threshold=values
discrete_label = AsDiscrete(to_onehot=None, threshold=0.5) #originally not only [0,1] but PROSTATEx docu said it is binarized, bg=0 always

# %%
# evaluation loop
def validation(model, val_loader, dice_metric, device):
    model.eval()

    with torch.no_grad():
        for batch_data in val_loader:
            inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device),)# [batch, 3, 256, 256]
            with torch.cuda.amp.autocast():
                outputs_upsampled_v = model(inputs)

                outputs_upsampled_v = outputs_upsampled_v.unsqueeze(1) #[batch,1,3,256,256]
                outputs_upsampled_v = discrete_pred(outputs_upsampled_v)
                labels_v = labels.unsqueeze(1) #[batch,1,3,256,256]
                labels_v = discrete_label(labels_v)
            dice_metric(y_pred=outputs_upsampled_v, y=labels_v) #num_class=shape[1]
        mean_dice_val = dice_metric.aggregate().item()
        dice_metric.reset()
    #print(f"Evaluation finished! Average loss = {avg_loss:2.5f}")
    return mean_dice_val


#validation_loss = validation(model, val_loader, dice_metric, device)
#print(f"Evaluation finished! Average dice metric = {validation_loss:2.5f}")

# %% [markdown]
# #### Train

# %%
# saving the model
model_dir = os.path.join(cwd, "model_0716") #/content/drive/MyDrive/harini_lab/model_X
if path.exists(model_dir) == False:
  os.mkdir(model_dir)
  print(f"Create new folder {model_dir}")
model_name = "model_ADC_slice_fixed_dataaug_norm_diceCE_10iter.pth"
model_save_dir = os.path.join(model_dir, model_name)
print(model_save_dir)
# Out:
# /content/drive/MyDrive/harini_lab/model_0716/model_ADC_slice_fixed_dataaug_norm_diceCE_10iter.pth

# %%
# training loop
# 1 iters

def train(model, train_loader, loss_function, optimizer, scaler, device,
          metric_value_best, global_step_best,
          global_step_start, max_epochs, num_example):

    start_time = time.time()

    model.train()

    global_step = global_step_start
    num_example = num_example #the total number of images: 239+60
    ori_resolution = (256, 256)

    print(f"Training starts! Set to run {max_epochs} epochs")
    for epoch in range(global_step_start, max_epochs):
        epoch_loss = 0 # recalculate for each epoch
        for batch_data in train_loader: #239
            optimizer.zero_grad() #at the start
            inputs, labels = (batch_data["image"].to(device),batch_data["label"].to(device),)
            # Forward pass
            with torch.cuda.amp.autocast():
                outputs_upsampled = model(inputs) #[1,3,256,256]
                outputs_upsampled = outputs_upsampled.unsqueeze(1) #[batch, 1, 3,256,256]
                labels = labels.unsqueeze(1) #[batch, 1, 3,256,256]
                loss = loss_function(outputs_upsampled, labels)
            # Backward pass
            scaler.scale(loss).backward()
            #print(loss.item())
            epoch_loss += loss.item()
            #print(epoch_loss)
            scaler.unscale_(optimizer)
            scaler.step(optimizer)
            scaler.update()

        epoch_loss /= num_example #average loss over this epoch
        epoch_loss_values.append(epoch_loss)
        print(f"Training {epoch + 1} epoch (loss={epoch_loss:2.5f})")

        # Validation & Save Model
        if epoch % 10 == 0 or epoch + 1 == max_epochs: #hardcoded to 10 iter, may change later
            # Validation
            mean_dice_val = validation(model, val_loader, dice_metric, device)
            metric_values.append(mean_dice_val)
            # Save Model: best validation loss
            if mean_dice_val > metric_value_best: #using MONAI DiceMetric(): larger, better overlap
                metric_value_best = mean_dice_val
                global_step_best = epoch
                torch.save({
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'scaler_state_dict': scaler.state_dict(),
                    'epoch': epoch,
                    'best_epoch': global_step_best,
                    'epoch_loss_values': epoch_loss_values,
                    'metric_values': metric_values,
                }, model_save_dir)
                print(f"Model saved! Epoch ({epoch + 1} / {max_epochs}). Training loss={epoch_loss:2.5f}, Evaluation dice metric={mean_dice_val:2.5f}")
            else:
                print(f"Model NOT saved! Epoch ({epoch + 1} / {max_epochs}). Training loss={epoch_loss:2.5f}, Evaluation dice metric={mean_dice_val:2.5f}")

        global_step = epoch

    # Temporary:
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
        'epoch': global_step,
        'best_epoch': global_step_best,
        'epoch_loss_values': epoch_loss_values,
        'metric_values': metric_values,
    }, model_save_dir)
    print(f"Model saved! Epoch ({global_step + 1} / {max_epochs}).")


    # Finish Training
    end_time = time.time()
    total_time = end_time - start_time
    print(f"Training finished! Total time: {total_time:2.5f} seconds") #CSV dataset: 104sec/epoch; #Cache Dataset rate=1: 50sec/epoch
    return global_step, global_step_best, epoch_loss_values, metric_values, metric_value_best

# %%
# Call train(), need to re-Define first
num_example = 418 #523
epoch_loss_values = []
metric_values = []
metric_value_best = 0.0 #using DiceCELoss, change to dicemetric() later????

global_step_best = 0 #change to continue training
global_step = 0 #change to continue training

# %%
print(f"global_step: {global_step}, global_step_best: {global_step_best}, metric_value_best: {metric_value_best}")
print(len(epoch_loss_values))
print(len(metric_values))
# Out:
# global_step: 0, global_step_best: 0, metric_value_best: 0.0
# 0
# 0

# %%
# Call train() separately, for continuous training
max_epochs = 20
global_step += 1 #continue without repeat
global_step, global_step_best, epoch_loss_values, metric_values, metric_value_best = train(model, train_loader, loss_function, optimizer, scaler, device,
                                                                                           metric_value_best, global_step_best,
                                                                                           global_step, max_epochs, num_example)
# Out:
# Training starts! Set to run 20 epochs
# Training 2 epoch (loss=0.45149)
# Training 3 epoch (loss=0.44489)
# Training 4 epoch (loss=0.44450)
# Training 5 epoch (loss=0.44442)
# Training 6 epoch (loss=0.44445)
# Training 7 epoch (loss=0.44449)
# Training 8 epoch (loss=nan)
# Training 9 epoch (loss=nan)
# Training 10 epoch (loss=nan)
# Training 11 epoch (loss=0.44437)
# Model NOT saved! Epoch (11 / 20). Training loss=0.44437, Evaluation dice metric=0.00000
# Training 12 epoch (loss=nan)
# Training 13 epoch (loss=nan)
# Training 14 epoch (loss=nan)
# Training 15 epoch (loss=nan)
# Training 16 epoch (loss=nan)
# Training 17 epoch (loss=nan)
# Training 18 epoch (loss=nan)
# Training 19 epoch (loss=nan)
# Training 20 epoch (loss=nan)
# Model NOT saved! Epoch (20 / 20). Training loss=nan, Evaluation dice metric=0.00000
# Model saved! Epoch (20 / 20).
# Training finished! Total time: 199.00532 seconds

# %%
# Save the model
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'scaler_state_dict': scaler.state_dict(),
    'epoch': global_step,
    'best_epoch': global_step_best,
    'epoch_loss_values': epoch_loss_values,
    'metric_values': metric_values,
}, model_save_dir)

# %%
# Load the model
checkpoint = torch.load(model_save_dir)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scaler.load_state_dict(checkpoint['scaler_state_dict'])
global_step = checkpoint['epoch']
global_step_best = checkpoint['best_epoch']
epoch_loss_values = checkpoint['epoch_loss_values']
metric_values = checkpoint['metric_values']

# %% [markdown]
# #### Check training output (val)

# %%
#validation_loss = validation(model, val_loader, loss_function, device)
#print(f"Evaluation finished! Average loss = {validation_loss:2.5f}")

# %%
def test_save(model, test_loader, loss_function, device): #save testing images
    model.eval()
    eval_metrics = [] #using loss for now??

    with torch.no_grad():
        for batch_data in val_loader:
            inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device),) #[batch,3,256,256]
            with torch.cuda.amp.autocast():
                outputs_upsampled_v = model(inputs)

                outputs_upsampled_v = outputs_upsampled_v.unsqueeze(1) #[batch,1,3,256,256]
                outputs_upsampled_v = discrete_pred(outputs_upsampled_v)
                labels_v = labels.unsqueeze(1) #[batch,1,3,256,256]
                labels_v = discrete_label(labels_v)

            dice_metric(y_pred=outputs_upsampled_v, y=labels_v) #num_class=shape[1]
            mean_dice_val = dice_metric.aggregate().item()
            dice_metric.reset()
            eval_metrics.append(mean_dice_val)
            #print(f"Validation (loss={metric:2.5f})")
    #print(f"Evaluation finished! Average loss = {avg_loss:2.5f}")
    return eval_metrics

# %%
# Example validation image
model.eval()
#model.train()
val_i = 0
for batch_data in val_loader:
    val_i += 1
    if val_i == 10: #change
        break

inputs, labels = (batch_data["image"].to(device), batch_data["label"].to(device),) #[batch,3,256,256]
outputs_upsampled = model(inputs)

# %%
#check
print(batch_data["image"].shape)
print(labels.shape)
print(outputs_upsampled.shape)
results_upsampled = outputs_upsampled.cpu().detach().numpy()
inputs_for_eval = inputs.cpu()
labels_for_eval = labels.cpu()

# Thresholding to get binary mask????
threshold = 0.5
binary_masks = (results_upsampled > threshold) #[6,1,256,256]

fig = plt.figure(figsize=(15, 10))
for j in range(3):
    a = fig.add_subplot(12, 3, j+1); a.set_title("original image", fontsize=8); a.axis("off");
    plt.imshow(inputs_for_eval[0,j,:,:].T, cmap="gray")

    a = fig.add_subplot(12, 3, j+1+3); a.set_title("original mask", fontsize=8);a.axis("off");
    plt.imshow(labels_for_eval[0,j,:,:].T, cmap="gray")

    a = fig.add_subplot(12, 3, j+1+6);a.set_title("Interp output", fontsize=8); a.axis("off");
    imgplot = plt.imshow(results_upsampled[0,j,:,:].T,vmin=0,vmax=1)

    a = fig.add_subplot(12, 3, j+1+9);a.set_title("Interp output(mask)", fontsize=8);a.axis("off");
    plt.imshow(binary_masks[0,j,:,:].T)

fig.suptitle("Example slices from val_dataset {}".format(batch_data["ID"]),fontsize=10)
cbar_ax = fig.add_axes([0.93, 0.6, 0.01, 0.2]) #[right,up,thickness,length]
fig.colorbar(imgplot, cax=cbar_ax)
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
#check
print(inputs.max()) #normalized [0,1]
print(inputs.min())

#results_upsampled.max() #-3.0733058: this is a feature map, not probability?
#results_upsampled.min() #-6.5495143
print(results_upsampled.max()) #0.54454064: after applying sigmoid(), it is a probability?
print(results_upsampled.min()) #0.3701884
# Out:
# metatensor(0.7677, device='cuda:0')
# metatensor(0., device='cuda:0')
# 2.3204804e-33
# 0.0

# %%
# try mean Intersection over Union (mIoU)
# need to handle [nan]
from monai.metrics import compute_iou, DiceMetric
label_for_eval = labels_for_eval[:,0,:,:].unsqueeze(1)
binary_mask = from_numpy(binary_masks)
#iou_metric = compute_iou(binary_mask, label_for_eval)
dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False) #function
dice_value = dice_metric(binary_mask, label_for_eval)
print(dice_value) #ERROR: nan???
# Out:
# metatensor([[0., 0., nan],
#         [0., 0., nan]])

# %%
print(epoch_loss_values)
print(metric_values)
# Out:
# [0.9772365781552622]
# [0.005922770127654076]

# %%
# Check loss & metrics
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch BCEWithLogitsLoss"); plt.xlabel(f"Epochs ({num_example} images/epoch)")
x = [i+1 for i in range(len(epoch_loss_values))] #239 steps per iter /num_example
y = epoch_loss_values
plt.plot(x, y)

plt.subplot(1, 2, 2)
plt.title("Val BCEWithLogitsLoss"); plt.xlabel("Validation Images Index (/10 epochs)")
x = [(i)*10 for i in range(len(metric_values))]
y = metric_values
plt.plot(x, y)

plt.suptitle(f"Result from {model_name}")
plt.show()

# %% [markdown]
# ## DeepLabv3-MobileViTv2 w/ given weights?
#
# For segmentation, there are training on 'ADE20K Dataset' & 'Pascal VOC 2012 Dataset' for DeepLabv3 MobileViTv2-1.0
#
# Github: https://github.com/apple/ml-cvnets/blob/main/docs/source/en/general/README-model-zoo.md#pascal-voc-2012-dataset

# %% [markdown]
# ### Try Custom Head (ignore for now)

# %%
#experiment block (ignore for now)
#https://pytorch.org/vision/main/_modules/torchvision/models/segmentation/deeplabv3.html
import torch
import torch.nn as nn

class DeepLabHeadCustom(nn.Module):
    def __init__(self, in_channels, num_classes=1, atrous_rates):
        atrous_rates = (6, 12, 18)
        out_channels = 256

        super(DeepLabHeadCustom, self).__init__()
        self.aspp = ASPP(in_channels, out_channels, atrous_rates)
        self.classifier = nn.Conv2d(out_channels, num_classes, kernel_size=1)

    def forward(self, x):
        x = self.aspp(x)
        x = self.decoder(x)
        return x

class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels, atrous_rates):
        super(ASPP, self).__init__()
        self.in_proj = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        out_proj = nn.Conv2d(5 * out_channels, out_channels, kernel_size=1) #why hard code as 5? num of feature maps??

        modules = [in_proj]
        modules.extend([
          nn.Conv2d(in_channels, out_channels, kernel_size=3, dilation=atrous_rates[0]),
          nn.Conv2d(in_channels, out_channels, kernel_size=3, dilation=atrous_rates[1]),
          nn.Conv2d(in_channels, out_channels, kernel_size=3, dilation=atrous_rates[2])
        ])
        modules.append(
            ASPPPooling(opts=opts, in_channels=in_channels, out_channels=out_channels)
        )

        self.convs = nn.ModuleList(modules)
        self.project = out_proj

        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x1 = self.relu(self.batch_norm(self.conv1(x)))
        x2 = self.relu(self.batch_norm(self.conv2(x)))
        x3 = self.relu(self.batch_norm(self.conv3(x)))
        x4 = self.relu(self.batch_norm(self.conv4(x)))

        out = []
        for conv in self.convs:
            out.append(conv(x))
        out = torch.cat(out, dim=1)
        out = self.project(out)
        out = self.dropout_layer(out)
        return out
        #return torch.cat([x1, x2, x3, x4], dim=1)

class ASPPPooling(nn.Sequential):
    def __init__(self, in_channels: int, out_channels: int) -> None:
        super().__init__(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, out_channels, kernel_size=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        size = x.shape[-2:]
        for mod in self:
            x = mod(x)
        return F.interpolate(x, size=size, mode="bilinear", align_corners=False)

# Initialize the model
model = DeepLabHeadCustom(in_channels=512, num_classes=1, atrous_rates=(6, 12, 18))

# Example input tensor
input_tensor = torch.randn(6, 512, 32, 32)

# Forward pass
output = model(input_tensor)
print(output.shape)
# Out:
#   File "<ipython-input-3-7dccfbfa3f43>", line 28
#     nn.Conv2d(in_channels, out_channels, kernel_size=3, dilation=atrous_rates[0])
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Try Transformer package?

# %%
class MobileViT_DeepLabV3(nn.Module):
    def __init__(self, backbone, seg_head):
        super(MobileViT_DeepLabV3, self).__init__()
        self.backbone = backbone
        self.seg_head = seg_head
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, return_intermediate=False):
        outputs_base = self.backbone(x)
        inputs_seg = outputs_base['last_hidden_state'].to(device) #[batch, 256/512/1024, 8/32, 8/32] feature maps #backprop???
        outputs_seg = self.seg_head(inputs_seg) #[batch, 1, 8/32, 8/32] MetaTensor
        # need softmax(multiclass)/sigmoid(binary) activation to turn feature map into segmentation probability
        outputs_active = self.sigmoid(outputs_seg) #[batch, 1, 32, 32] #ex.max=0.8551, min=0.1949
        #print(outputs_active.max())
        #print(outputs_active.min())
        outputs_upsampled = F.interpolate(outputs_active, size=x.shape[-2:], mode='bilinear', align_corners=False) #[6, 1, 256, 256] #ex. max=0.8345, min=0.2594
        # assert(x.shape[-2:]==[256,256])
        # need a way to check outputs_seg, but cannot affect backprop
        #if return_intermediate:
        #    return outputs_upsampled, outputs_seg
        #else:
        return outputs_upsampled #outputs_upsampled

# %%
#https://github.com/huggingface/transformers/blob/main/src/transformers/models/mobilevitv2/modeling_mobilevitv2.py
#https://huggingface.co/docs/transformers/en/model_doc/mobilevitv2

import requests
import torch
from PIL import Image
from transformers import AutoImageProcessor, MobileViTV2ForSemanticSegmentation, AutoModel

base_model = AutoModel.from_pretrained("apple/mobilevitv2-1.0-voc-deeplabv3") #MobileViTV2ForSemanticSegmentation
#WARNING:
#Some weights of MobileViTV2ForSemanticSegmentation were not initialized from the model checkpoint at apple/mobilevitv2-1.0-imagenet1k-256 and are newly initialized: ['segmentation_head.aspp.convs.0.convolution.weight', 'segmentation_head.aspp.convs.0.normalization.bias', 'segmentation_head.aspp.convs.0.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.0.normalization.running_mean', 'segmentation_head.aspp.convs.0.normalization.running_var', 'segmentation_head.aspp.convs.0.normalization.weight', 'segmentation_head.aspp.convs.1.convolution.weight', 'segmentation_head.aspp.convs.1.normalization.bias', 'segmentation_head.aspp.convs.1.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.1.normalization.running_mean', 'segmentation_head.aspp.convs.1.normalization.running_var', 'segmentation_head.aspp.convs.1.normalization.weight', 'segmentation_head.aspp.convs.2.convolution.weight', 'segmentation_head.aspp.convs.2.normalization.bias', 'segmentation_head.aspp.convs.2.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.2.normalization.running_mean', 'segmentation_head.aspp.convs.2.normalization.running_var', 'segmentation_head.aspp.convs.2.normalization.weight', 'segmentation_head.aspp.convs.3.convolution.weight', 'segmentation_head.aspp.convs.3.normalization.bias', 'segmentation_head.aspp.convs.3.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.3.normalization.running_mean', 'segmentation_head.aspp.convs.3.normalization.running_var', 'segmentation_head.aspp.convs.3.normalization.weight', 'segmentation_head.aspp.convs.4.conv_1x1.convolution.weight', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.bias', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.running_mean', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.running_var', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.weight', 'segmentation_head.aspp.project.convolution.weight', 'segmentation_head.aspp.project.normalization.bias', 'segmentation_head.aspp.project.normalization.num_batches_tracked', 'segmentation_head.aspp.project.normalization.running_mean', 'segmentation_head.aspp.project.normalization.running_var', 'segmentation_head.aspp.project.normalization.weight', 'segmentation_head.classifier.convolution.bias', 'segmentation_head.classifier.convolution.weight']
#You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

seg_model = DeepLabHead(
    in_channels=512,  # Adjust if feature map from base_model differ
    num_classes=3,  # matching the input channel in mobilevitv2
    atrous_rates=(6,12,18) #from the paper, PyTorch default (12,24,36)
).to(device)

model = MobileViT_DeepLabV3(base_model, seg_model).to(device)

# %%
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

image_processor = AutoImageProcessor.from_pretrained("apple/mobilevitv2-1.0-voc-deeplabv3")  #apple/mobilevitv2-1.0-imagenet1k-256
inputs = image_processor(images=image, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8e1b60250835> in <cell line: 2>()
#       1 url = "http://images.cocodataset.org/val2017/000000039769.jpg"
# ----> 2 image = Image.open(requests.get(url, stream=True).raw)
#       3
#       4 image_processor = AutoImageProcessor.from_pretrained("apple/mobilevitv2-1.0-voc-deeplabv3")  #apple/mobilevitv2-1.0-imagenet1k-256
#       5 inputs = image_processor(images=image, return_tensors="pt")
#
# NameError: name 'Image' is not defined

# %%
print(outputs[-1]) #[1,512,32,32]
# Out:
# tensor([[-7.2801e-02,  8.5267e-02, -2.9638e-02,  6.7401e-02, -8.7815e-02,
#           4.0720e-01,  2.9348e-02, -3.2629e-01,  6.1326e-01,  6.2719e-01,
#           1.4558e-01, -9.2261e-02, -4.3833e-01, -4.1101e-03,  1.2911e-02,
#           8.9667e-02, -5.5024e-01, -1.2729e-01,  8.7860e-02,  1.3362e-02,
#          -4.5252e-01,  2.0839e-01, -8.2026e-02,  7.5711e-02, -7.3276e-02,
#          -4.2018e-02, -2.5275e-03, -2.7667e-01,  6.6404e-01, -2.8436e-01,
#           4.7972e-02,  3.8975e-01, -3.1527e-01,  8.5884e-01,  6.4614e-02,
#          -6.3035e-01, -7.2355e-02, -6.2014e-02,  7.2393e-01, -8.0131e-03,
#           6.7259e-02, -4.5150e-03, -1.2911e-03,  9.3672e-02,  2.0740e-01,
#           2.8714e-02,  5.4417e-01,  9.9893e-02, -3.0579e-01,  8.8153e-01,
#          -3.9888e-02,  1.6500e-03,  1.1752e+00,  4.7328e-01,  8.5680e-02,
#           4.4898e-02, -5.2006e-01, -4.9137e-01,  6.6981e-02,  7.0853e-01,
#          -1.4826e-02, -6.4402e-03, -8.5003e-02, -7.8465e-02,  1.0487e-02,
#           7.3618e-02, -8.9106e-02, -4.6339e-03,  3.8093e-01, -8.0641e-02,
#           4.4672e-01,  6.6843e-02, -8.4777e-02,  3.5789e-02, -8.4467e-02,
#           6.9325e-02,  7.0750e-02,  4.9357e-02, -4.8328e-03,  1.4438e-02,
#           5.5744e-01, -5.0054e-04, -2.8620e-01,  4.5385e-02,  1.9051e-01,
#          -2.9171e-01,  2.7247e-02,  1.0204e-01,  2.9280e-01, -4.4192e-03,
#          -5.1831e-01,  3.6863e-01, -5.1531e-02, -1.3824e+00,  1.0780e+00,
#           6.5572e-02,  2.8452e-03,  9.5872e-02,  2.5317e-02, -1.2908e+00,
#           2.8965e-03, -4.6716e-01,  2.1006e-01,  6.4144e-02,  3.9504e-02,
#           1.0589e-01,  8.8174e-02, -4.1699e-01,  9.5183e-02, -1.1036e+00,
#          -5.7813e-03, -2.0242e-01,  1.5663e-02, -9.7577e-02,  3.9164e-02,
#           3.0995e-02, -9.6509e-01,  7.9728e-01,  3.5534e-01,  6.7431e-01,
#          -1.9914e-01, -5.8814e-03,  1.4759e-01,  2.7846e-01, -1.8430e-02,
#           3.8377e-02, -4.3749e-02,  9.2458e-02, -1.9311e-01,  8.2657e-02,
#           1.0533e-01,  1.0992e-02,  4.3585e-01, -6.3563e-02,  7.2196e-02,
#          -9.0638e-02,  3.4240e-01, -6.0918e-01,  2.2404e-02,  6.1365e-03,
#          -7.6658e-01,  5.1517e-02,  8.4058e-02, -4.4704e-02,  1.4694e-01,
#          -9.3748e-01, -8.0319e-02,  3.2009e-01,  7.9136e-02, -4.9257e-02,
#          -4.9648e-02,  3.7791e-01, -1.0037e+00, -7.6790e-01, -2.9525e-01,
#          -1.0017e+00, -5.5883e-02,  7.5470e-02,  4.0200e-02, -6.0409e-02,
#          -9.8351e-02, -1.2962e-01,  3.8724e-03, -1.0622e-02, -1.0955e-03,
#           8.8150e-02,  1.0830e-01,  2.3071e-04,  4.7342e-02, -2.6024e-01,
#           2.6287e-02,  7.1348e-02, -8.7497e-02, -2.7609e-01,  2.5401e-04,
#          -8.7299e-01,  4.7160e-02, -6.0250e-02,  6.3383e-01,  4.1635e-02,
#          -3.0657e-02,  7.9458e-02, -2.2542e-01,  2.3725e-01,  5.3153e-01,
#           3.0612e-01, -2.1955e-03,  6.1124e-01, -9.3628e-01, -5.5606e-04,
#          -6.5716e-02,  2.8508e-02, -3.4041e-01, -1.6232e-02,  5.3598e-01,
#          -2.5521e-01,  8.4671e-02, -6.6784e-02,  2.1599e-02, -3.4909e-01,
#           1.0271e+00,  3.6947e-01, -5.6095e-02, -8.1099e-02,  4.9893e-02,
#          -1.2439e-02, -5.7252e-02, -7.3122e-02, -8.7164e-02, -2.2303e-03,
#          -8.7644e-02,  7.3816e-02, -7.7947e-01,  1.0131e-03, -5.8553e-01,
#           4.7476e-01,  8.4210e-02, -2.0793e-03,  2.4873e-03,  5.7190e-01,
#          -7.5051e-02, -1.8802e-02,  1.1984e-02,  8.2034e-02,  4.7336e-01,
#          -1.9549e-01, -1.1295e-02,  8.9750e-02, -6.3909e-02, -3.8259e-02,
#          -3.3945e-01,  1.3108e-01, -5.3263e-01, -3.9152e-01,  3.7312e-01,
#          -1.8174e-03,  6.4598e-01,  3.1213e-01,  6.6328e-02, -2.2575e-02,
#          -2.1954e-01,  8.8502e-02,  6.6237e-01, -3.7036e-01,  4.2694e-01,
#           3.7587e-01, -6.8283e-02,  5.6046e-01,  3.5524e-03,  4.3674e-02,
#           8.7734e-02, -1.4302e-03,  5.7752e-03,  1.1600e-04,  9.0935e-02,
#           6.1069e-02, -3.9977e-02,  2.4694e-01, -1.1811e-01, -6.7445e-02,
#           2.5041e-02,  6.6690e-02, -4.8854e-01, -1.0134e-01, -8.1255e-02,
#           9.2862e-02,  8.1739e-02, -6.8035e-02,  5.2677e-02, -6.6408e-01,
#           1.2844e-01, -7.4497e-02,  1.3399e-02,  8.7030e-05, -1.6936e-02,
#           1.0409e+00, -1.5121e-02, -2.5308e-01,  3.6418e-01, -8.2559e-02,
#          -1.1944e-01, -2.9586e-02,  5.2025e-02, -3.6449e-03, -4.7965e-01,
#           8.6441e-02,  1.0958e+00,  4.1060e-01, -7.0461e-01,  3.3436e-01,
#          -5.9440e-02,  3.6628e-01, -5.9886e-01,  3.3915e-01, -8.4385e-02,
#           4.8641e-01,  1.1400e+00,  1.6599e-01,  8.0186e-04, -6.5383e-02,
#           7.6892e-02,  2.7201e-02,  6.2390e-02, -2.7038e-02,  9.2616e-02,
#          -3.0764e-01, -5.5215e-01, -7.9124e-02, -7.3691e-01, -4.2557e-01,
#           7.3780e-01,  7.8820e-02, -3.8956e-01,  2.4560e-04, -8.2062e-02,
#           6.0680e-03, -8.3782e-02,  9.0552e-02,  2.3258e-02, -5.1940e-01,
#           9.0412e-02,  4.0892e-02,  8.1079e-02,  7.9279e-01, -1.9042e-03,
#           4.7627e-01,  1.1607e-01,  8.4082e-02,  2.3406e-01,  1.8490e-01,
#          -7.0122e-02, -1.2794e-01,  8.6332e-01, -5.6895e-02, -3.2590e-02,
#           2.4115e-03,  5.3603e-02, -3.2754e-01,  4.8394e-01,  2.4278e-02,
#          -4.5932e-02, -3.3641e-01,  1.4456e-02, -2.5795e-01, -4.6548e-01,
#          -4.7010e-01,  6.4600e-02,  9.9826e-01,  1.1750e+00,  5.7552e-01,
#          -8.5755e-02,  6.8914e-01,  3.9085e-02,  3.5819e-01, -2.9349e-01,
#           6.0190e-01, -1.9541e-01, -6.8934e-02, -3.0909e-03, -7.3626e-02,
#          -4.9093e-03, -2.2060e-01,  6.9614e-02,  8.3626e-02, -7.7988e-03,
#           5.0374e-02, -8.2151e-01, -2.9952e-01,  2.1398e-01,  2.0996e-02,
#           3.7845e-01,  5.2849e-01,  4.5624e-02,  4.3910e-02, -1.1946e-01,
#           3.8655e-01,  9.0076e-02,  4.3124e-01,  1.8629e-01,  9.7412e-01,
#          -2.0547e-03, -8.3648e-02, -8.4314e-01,  1.6553e-01, -8.0306e-02,
#           7.7387e-02, -4.1782e-01,  7.5782e-02, -6.5302e-02, -9.1772e-02,
#           2.0954e-01,  2.2532e-01,  2.6675e-02,  8.0991e-02, -7.3383e-02,
#          -2.5486e-01, -8.8780e-02,  8.2363e-02, -2.2688e-01,  1.2847e-01,
#          -2.0887e-01,  2.0205e-03, -3.7396e-02,  8.9035e-02,  8.4001e-02,
#           9.0091e-01,  3.3000e-01,  5.9191e-01, -2.0352e-01, -8.6490e-02,
#           4.1445e-02,  9.1516e-02, -9.8082e-01,  7.4471e-02,  5.3656e-03,
#          -6.6367e-02, -4.6604e-02, -1.0217e-02,  6.4636e-01,  8.9289e-02,
#          -4.0816e-01, -2.9711e-02, -7.5871e-02, -2.8604e-01,  3.6364e-03,
#           9.0846e-02, -1.6861e-01, -1.5596e-02, -8.1644e-02,  7.8297e-02,
#           9.7158e-03,  1.0149e-02, -4.8674e-01,  4.0422e-02,  1.2688e-03,
#           8.2329e-01,  5.0624e-01, -1.8400e-03,  6.9737e-02, -3.8723e-01,
#           5.1853e-01,  4.2794e-02, -1.1899e-01,  3.7061e-01,  5.9312e-02,
#          -4.0290e-01, -1.1959e-02,  1.3457e-02,  1.1764e-04, -8.7530e-02,
#          -1.3084e+00, -6.7034e-02, -5.3528e-03,  3.8249e-02, -7.0948e-02,
#          -9.9825e-02,  6.7644e-02,  5.6330e-01, -4.8744e-01,  5.2731e-01,
#           1.5347e-02,  1.7003e+00, -1.3069e-03,  3.8720e-03, -1.4958e-02,
#           2.6501e-01,  8.6213e-02, -7.8388e-02, -4.2825e-01, -1.0902e+00,
#           3.1292e-03, -2.3353e-01,  4.1408e-01,  6.1990e-01,  4.8350e-01,
#          -6.8067e-02,  9.3571e-02, -5.0046e-02,  9.6296e-02, -3.8290e-01,
#           3.4595e-01, -6.4640e-01,  7.9259e-01, -7.9494e-02,  4.0798e-02,
#          -7.3216e-02, -6.6376e-02,  1.8994e-01,  7.6534e-02, -1.5629e-01,
#           6.3633e-02,  5.7134e-02, -7.9698e-01, -8.9880e-02, -5.7273e-01,
#           6.1719e-02,  5.4450e-01, -3.1840e-02,  3.8099e-02,  9.3034e-02,
#           5.4471e-02, -1.4699e+00,  2.5863e-01,  5.7114e-02,  4.8106e-01,
#           3.2261e-02, -1.6303e-01, -8.0492e-02, -2.3099e-01, -5.8255e-02,
#           1.2203e-01,  3.8739e-02]])

# %% [markdown]
# ### Model tutorials

# %%
import requests
import torch
from PIL import Image
from transformers import AutoImageProcessor, MobileViTV2ForSemanticSegmentation, AutoModel

image_processor = AutoImageProcessor.from_pretrained("apple/mobilevitv2-1.0-voc-deeplabv3")  #apple/mobilevitv2-1.0-imagenet1k-256
model = MobileViTV2ForSemanticSegmentation.from_pretrained("apple/mobilevitv2-1.0-voc-deeplabv3")
#WARNING:
#Some weights of MobileViTV2ForSemanticSegmentation were not initialized from the model checkpoint at apple/mobilevitv2-1.0-imagenet1k-256 and are newly initialized: ['segmentation_head.aspp.convs.0.convolution.weight', 'segmentation_head.aspp.convs.0.normalization.bias', 'segmentation_head.aspp.convs.0.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.0.normalization.running_mean', 'segmentation_head.aspp.convs.0.normalization.running_var', 'segmentation_head.aspp.convs.0.normalization.weight', 'segmentation_head.aspp.convs.1.convolution.weight', 'segmentation_head.aspp.convs.1.normalization.bias', 'segmentation_head.aspp.convs.1.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.1.normalization.running_mean', 'segmentation_head.aspp.convs.1.normalization.running_var', 'segmentation_head.aspp.convs.1.normalization.weight', 'segmentation_head.aspp.convs.2.convolution.weight', 'segmentation_head.aspp.convs.2.normalization.bias', 'segmentation_head.aspp.convs.2.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.2.normalization.running_mean', 'segmentation_head.aspp.convs.2.normalization.running_var', 'segmentation_head.aspp.convs.2.normalization.weight', 'segmentation_head.aspp.convs.3.convolution.weight', 'segmentation_head.aspp.convs.3.normalization.bias', 'segmentation_head.aspp.convs.3.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.3.normalization.running_mean', 'segmentation_head.aspp.convs.3.normalization.running_var', 'segmentation_head.aspp.convs.3.normalization.weight', 'segmentation_head.aspp.convs.4.conv_1x1.convolution.weight', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.bias', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.num_batches_tracked', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.running_mean', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.running_var', 'segmentation_head.aspp.convs.4.conv_1x1.normalization.weight', 'segmentation_head.aspp.project.convolution.weight', 'segmentation_head.aspp.project.normalization.bias', 'segmentation_head.aspp.project.normalization.num_batches_tracked', 'segmentation_head.aspp.project.normalization.running_mean', 'segmentation_head.aspp.project.normalization.running_var', 'segmentation_head.aspp.project.normalization.weight', 'segmentation_head.classifier.convolution.bias', 'segmentation_head.classifier.convolution.weight']
#You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
inputs = image_processor(images=image, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

# logits are of shape (batch_size, num_labels, height, width)
logits = outputs.logits #[1, 21, 32, 32]
print(logits.shape)
# Out:
# torch.Size([1, 21, 32, 32])

# %%
print(inputs["pixel_values"].max())
print(inputs["pixel_values"].min())
# Out:
# tensor(1.)
# tensor(0.)

# %%
from urllib.request import urlopen
from PIL import Image
import timm

img = Image.open(urlopen(
    'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/beignets-task-guide.png'
))

model = timm.create_model('mobilevit_xxs.cvnets_in1k', pretrained=True)
model = model.eval()

# get model specific transforms (normalization, resize)
data_config = timm.data.resolve_model_data_config(model)
transforms = timm.data.create_transform(**data_config, is_training=False)
inputs = transforms(img).unsqueeze(0)

output = model(inputs)  # unsqueeze single image into batch of 1

top5_probabilities, top5_class_indices = torch.topk(output.softmax(dim=1) * 100, k=5)

# %%
print(np.max(img))
print(np.min(img))

print(inputs.max())
print(inputs.min())
print(torch.mean(inputs))
print(torch.std(inputs))
# Out:
# 255
# 0
# tensor(1.)
# tensor(0.)
# tensor(0.6979)
# tensor(0.2212)

# %%
print(transforms)
# Out:
# Compose(
#     Resize(size=284, interpolation=bicubic, max_size=None, antialias=True)
#     CenterCrop(size=(256, 256))
#     ToTensor()
#     Normalize(mean=tensor([0., 0., 0.]), std=tensor([1., 1., 1.]))
# )
